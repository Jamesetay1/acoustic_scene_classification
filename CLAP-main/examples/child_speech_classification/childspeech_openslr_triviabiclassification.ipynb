# %%
from msclap import CLAP
import torch
import torch.nn.functional as F
import numpy as np
from tqdm import tqdm
from sklearn.metrics import accuracy_score
import pandas as pd
import os
import pickle
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_pickle('/work/data_pipeline/audio_data/preprocessing/web_free_source_raw/OpenSLR/SLR101/meta_metrics.pkl').dropna()
child = df[df['age'].astype(int) <= 16]
child['class'] = 'child'
#display(kids)

df = pd.read_pickle('/work/data_pipeline/audio_data/preprocessing/web_free_source_raw/OpenSLR/SLR101/meta_metrics.pkl').dropna()
adult = df[df['age'].astype(int) > 16]
adult['class'] = 'adult'
#display(adult)

# %%
#Create single df 
df = pd.concat([child[['filepath', 'class', 'age', 'gender']], adult[['filepath', 'class', 'age', 'gender']]])
display(df)
# Out:
#                                                filepath  class age gender
# 0     /work/data_pipeline/audio_data/preprocessing/w...  child   7      m
# 3     /work/data_pipeline/audio_data/preprocessing/w...  child   9      m
# 4     /work/data_pipeline/audio_data/preprocessing/w...  child  10      m
# 5     /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 6     /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# ...                                                 ...    ...  ..    ...
# 5230  /work/data_pipeline/audio_data/preprocessing/w...  adult  23      m
# 5233  /work/data_pipeline/audio_data/preprocessing/w...  adult  20      f
# 5234  /work/data_pipeline/audio_data/preprocessing/w...  adult  37      m
# 5241  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5243  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
#
# [4999 rows x 4 columns]

# %%
classes = df['class'].unique()

class_id_map = {name: i for i, name in enumerate(classes, 0)}
id_to_class = {v: k for k, v in class_id_map.items()}
print(class_id_map)

prompt = 'The speaker is the age of a:'
y = [prompt + x for x in classes]
# Out:
# {'child': 0, 'adult': 1}

# %%
# Load and initialize CLAP
clap_model = CLAP(version = '2023', use_cuda=True)

# Computing text embeddings
text_embeddings = clap_model.get_text_embeddings(y)

# %%
# Computing audio embeddings
y_preds, y_labels = [], []
print(os.getcwd())

for i in tqdm(range(len(df))):
    path, label, age, gender = df.iloc[i]
    idx = class_id_map[label]
    #print(idx)
    one_hot_target = torch.nn.functional.one_hot(torch.tensor([idx]), num_classes=len(classes)+1)

    audio_embeddings = clap_model.get_audio_embeddings([path], resample=True)
    similarity = clap_model.compute_similarity(audio_embeddings, text_embeddings)

    y_pred = F.softmax(similarity.detach().cpu(), dim=1).numpy()

    y_preds.append(y_pred)
    y_labels.append(one_hot_target.detach().cpu().numpy())
# Out:
# /mounts/ud-data/jtaylor/a5f2c23d-7fb6-41a6-ac0c-3a2ffc02b992/data/acoustic_scene_classification/CLAP-main/examples/child_speech_classification
# 100%|██████████| 4999/4999 [10:01<00:00,  8.31it/s]

# %%
y_lab, y_pred = np.concatenate(y_labels, axis=0), np.concatenate(y_preds, axis=0)
y_label_val = np.argmax(y_lab, axis=1)
y_pred_val = np.argmax(y_pred, axis=1)
acc = accuracy_score(np.argmax(y_lab, axis=1), np.argmax(y_pred, axis=1))
print('Accuracy {}'.format(acc))
# Out:
# Accuracy 0.6689337867573515

# %%
# get confusion matrix
conf_matrix = confusion_matrix(y_label_val,y_pred_val)
conf_mat_norm_recall = conf_matrix.astype('float32')/conf_matrix.sum(axis=1)[:,np.newaxis]
recall_by_class = np.diagonal(conf_mat_norm_recall)
mean_recall = np.mean(recall_by_class)

# Calculate row sums to use for percentages
row_sums = conf_matrix.sum(axis=1)

# Calculate percentages
percentages = (conf_matrix.T / row_sums).T  # Transpose for division, then transpose back

# Format percentages as strings with '%' symbol
annot_data = [['{:.2f}'.format(val) for val in row] for row in percentages]
annot_data = [['' if float(val <= 0.04) else '{:.2f}'.format(val) for val in row] for row in percentages]

plt.figure(dpi=200)

annot_kws = {'size': 6}
ax = sns.heatmap(percentages, xticklabels=classes, yticklabels=classes, annot=annot_data, fmt='', square=True, cmap='Blues', annot_kws=annot_kws)
ax.set_xlabel('Predicted Label')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.set_ylabel('True Label')

#plt.subplots_adjust(left=0.2, bottom=0.35)
plt.show()

# %%
# Average for correct and incorrect
result = [a == b for a, b in zip(y_label_val, y_pred_val)]
df['predicted'] = [id_to_class[pred] for pred in y_pred_val]
df['correct'] = result

confidence = [y_preds[k][0][y_pred_val[k]] for k, pred in enumerate(y_preds)] 
df['confidence'] = confidence
display(df)

wrong_df = df[df['correct']==False]
correct_df = df[df['correct']==True]

print(np.mean(wrong_df['confidence']))
print(np.mean(correct_df['confidence']))
# Out:
#                                                filepath  class age gender  \
# 0     /work/data_pipeline/audio_data/preprocessing/w...  child   7      m
# 3     /work/data_pipeline/audio_data/preprocessing/w...  child   9      m
# 4     /work/data_pipeline/audio_data/preprocessing/w...  child  10      m
# 5     /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 6     /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# ...                                                 ...    ...  ..    ...
# 5230  /work/data_pipeline/audio_data/preprocessing/w...  adult  23      m
# 5233  /work/data_pipeline/audio_data/preprocessing/w...  adult  20      f
# 5234  /work/data_pipeline/audio_data/preprocessing/w...  adult  37      m
# 5241  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5243  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
#
#      predicted  correct  confidence
# 0        child     True    0.966762
# 3        child     True    0.524806
# 4        adult    False    0.500749
# 5        child     True    0.789359
# 6        child     True    0.632592
# ...        ...      ...         ...
# 5230     adult     True    0.927032
# 5233     child    False    0.519642
# 5234     adult     True    0.778748
# 5241     adult     True    0.834111
# 5243     child    False    0.957665
#
# [4999 rows x 7 columns]
# 0.75817376
# 0.8216849

# %%
predicted_as_child = df[df['predicted']=='child']
display(predicted_as_child)
# Out:
#                                                filepath  class age gender  \
# 0     /work/data_pipeline/audio_data/preprocessing/w...  child   7      m
# 3     /work/data_pipeline/audio_data/preprocessing/w...  child   9      m
# 5     /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 6     /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# 8     /work/data_pipeline/audio_data/preprocessing/w...  child   6      m
# ...                                                 ...    ...  ..    ...
# 5197  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5203  /work/data_pipeline/audio_data/preprocessing/w...  adult  33      f
# 5221  /work/data_pipeline/audio_data/preprocessing/w...  adult  22      f
# 5233  /work/data_pipeline/audio_data/preprocessing/w...  adult  20      f
# 5243  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
#
#      predicted  correct  confidence
# 0        child     True    0.966762
# 3        child     True    0.524806
# 5        child     True    0.789359
# 6        child     True    0.632592
# 8        child     True    0.828896
# ...        ...      ...         ...
# 5197     child    False    0.841786
# 5203     child    False    0.954465
# 5221     child    False    0.570164
# 5233     child    False    0.519642
# 5243     child    False    0.957665
#
# [3146 rows x 7 columns]

# %%
def calc_new_class(row):
    if int(row['age']) < 11:
        return 'False'
    else:
        return 'True'

# %%
predicted_as_child['class2'] = df.apply(calc_new_class, axis=1)
display(predicted_as_child)
# Out:
#                                                filepath  class age gender  \
# 0     /work/data_pipeline/audio_data/preprocessing/w...  child   7      m
# 3     /work/data_pipeline/audio_data/preprocessing/w...  child   9      m
# 5     /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 6     /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# 8     /work/data_pipeline/audio_data/preprocessing/w...  child   6      m
# ...                                                 ...    ...  ..    ...
# 5197  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5203  /work/data_pipeline/audio_data/preprocessing/w...  adult  33      f
# 5221  /work/data_pipeline/audio_data/preprocessing/w...  adult  22      f
# 5233  /work/data_pipeline/audio_data/preprocessing/w...  adult  20      f
# 5243  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
#
#      predicted  correct  confidence class2
# 0        child     True    0.966762  False
# 3        child     True    0.524806  False
# 5        child     True    0.789359   True
# 6        child     True    0.632592   True
# 8        child     True    0.828896  False
# ...        ...      ...         ...    ...
# 5197     child    False    0.841786   True
# 5203     child    False    0.954465   True
# 5221     child    False    0.570164   True
# 5233     child    False    0.519642   True
# 5243     child    False    0.957665   True
#
# [3146 rows x 8 columns]

# %%
classes = predicted_as_child['class2'].unique()

class_id_map = {name: i for i, name in enumerate(classes, 0)}
id_to_class = {v: k for k, v in class_id_map.items()}
print(class_id_map)

prompt = 'The speaker is older than eleven years old, True or False:'
y = [prompt + x for x in classes]
# Out:
# {'False': 0, 'True': 1}

# %%
# Load and initialize CLAP
clap_model = CLAP(version = '2023', use_cuda=True)

# Computing text embeddings
text_embeddings = clap_model.get_text_embeddings(y)

# Computing audio embeddings
y_preds, y_labels = [], []
print(os.getcwd())

for i in tqdm(range(len(predicted_as_child))):
    path, label = predicted_as_child.iloc[i][['filepath', 'class2']]
    idx = class_id_map[label]
    #print(idx)
    one_hot_target = torch.nn.functional.one_hot(torch.tensor([idx]), num_classes=len(classes)+1)

    audio_embeddings = clap_model.get_audio_embeddings([path], resample=True)
    similarity = clap_model.compute_similarity(audio_embeddings, text_embeddings)

    y_pred = F.softmax(similarity.detach().cpu(), dim=1).numpy()

    y_preds.append(y_pred)
    y_labels.append(one_hot_target.detach().cpu().numpy())
# Out:
# /mounts/ud-data/jtaylor/a5f2c23d-7fb6-41a6-ac0c-3a2ffc02b992/data/acoustic_scene_classification/CLAP-main/examples/child_speech_classification
# 100%|██████████| 3146/3146 [04:25<00:00, 11.85it/s]

# %%
y_lab, y_pred = np.concatenate(y_labels, axis=0), np.concatenate(y_preds, axis=0)
y_label_val = np.argmax(y_lab, axis=1)
y_pred_val = np.argmax(y_pred, axis=1)
acc = accuracy_score(np.argmax(y_lab, axis=1), np.argmax(y_pred, axis=1))
print('Accuracy {}'.format(acc))
# Out:
# Accuracy 0.6557533375715194

# %%
# get confusion matrix
conf_matrix = confusion_matrix(y_label_val,y_pred_val)
conf_mat_norm_recall = conf_matrix.astype('float32')/conf_matrix.sum(axis=1)[:,np.newaxis]
recall_by_class = np.diagonal(conf_mat_norm_recall)
mean_recall = np.mean(recall_by_class)

# Calculate row sums to use for percentages
row_sums = conf_matrix.sum(axis=1)

# Calculate percentages
percentages = (conf_matrix.T / row_sums).T  # Transpose for division, then transpose back

# Format percentages as strings with '%' symbol
annot_data = [['{:.2f}'.format(val) for val in row] for row in percentages]
annot_data = [['' if float(val <= 0.04) else '{:.2f}'.format(val) for val in row] for row in percentages]

plt.figure(dpi=200)

annot_kws = {'size': 6}
ax = sns.heatmap(percentages, xticklabels=classes, yticklabels=classes, annot=annot_data, fmt='', square=True, cmap='Blues', annot_kws=annot_kws)
ax.set_xlabel('Predicted Label')
ax.set_xticklabels(rotation=90)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.set_ylabel('True Label')

#plt.subplots_adjust(left=0.2, bottom=0.35)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 22
#      20 ax = sns.heatmap(percentages, xticklabels=classes, yticklabels=classes, annot=annot_data, fmt='', square=True, cmap='Blues', annot_kws=annot_kws)
#      21 ax.set_xlabel('Predicted Label')
# ---> 22 ax.set_xticklabels(rotation=90)
#      23 ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
#      24 ax.set_ylabel('True Label')
#
# File ~/.conda/envs/clap-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~/.conda/envs/clap-env/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# TypeError: Axis.set_ticklabels() missing 1 required positional argument: 'labels'

# %%
# Average for correct and incorrect
result = [a == b for a, b in zip(y_label_val, y_pred_val)]
predicted_as_child['predicted2'] = [id_to_class[pred] for pred in y_pred_val]
predicted_as_child['correct2'] = result

confidence = [y_preds[k][0][y_pred_val[k]] for k, pred in enumerate(y_preds)] 
predicted_as_child['confidence2'] = confidence
display(predicted_as_child)

wrong_df = predicted_as_child[predicted_as_child['correct']==False]
correct_df = predicted_as_child[predicted_as_child['correct']==True]

print(np.mean(wrong_df['confidence']))
print(np.mean(correct_df['confidence']))
# Out:
#                                                filepath  class age gender  \
# 0     /work/data_pipeline/audio_data/preprocessing/w...  child   7      m
# 3     /work/data_pipeline/audio_data/preprocessing/w...  child   9      m
# 5     /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 6     /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# 8     /work/data_pipeline/audio_data/preprocessing/w...  child   6      m
# ...                                                 ...    ...  ..    ...
# 5197  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5203  /work/data_pipeline/audio_data/preprocessing/w...  adult  33      f
# 5221  /work/data_pipeline/audio_data/preprocessing/w...  adult  22      f
# 5233  /work/data_pipeline/audio_data/preprocessing/w...  adult  20      f
# 5243  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
#
#      predicted  correct  confidence       class2   predicted2  correct2  \
# 0        child     True    0.966762  young child  young child      True
# 3        child     True    0.524805  young child  young child      True
# 5        child     True    0.789358     teenager  young child     False
# 6        child     True    0.632592     teenager  young child     False
# 8        child     True    0.828895  young child  young child      True
# ...        ...      ...         ...          ...          ...       ...
# 5197     child    False    0.841786     teenager  young child     False
# 5203     child    False    0.954465     teenager  young child     False
# 5221     child    False    0.570162     teenager     teenager      True
# 5233     child    False    0.519641     teenager  young child     False
# 5243     child    False    0.929455     teenager  young child     False
#
#       confidence2
# 0        0.988281
# 3        0.500758
# 5        0.803227
# 6        0.898097
# 8        0.833344
# ...           ...
# 5197     0.798248
# 5203     0.936837
# 5221     0.568529
# 5233     0.593435
# 5243     0.841027
#
# [3148 rows x 11 columns]
# 0.77462685
# 0.8733552

# %%
display(predicted_as_child[predicted_as_child['predicted2'] == 'teenager'])
# Out:
#                                                filepath  class age gender  \
# 25    /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 30    /work/data_pipeline/audio_data/preprocessing/w...  child   6      f
# 51    /work/data_pipeline/audio_data/preprocessing/w...  child   8      m
# 77    /work/data_pipeline/audio_data/preprocessing/w...  child  11      m
# 106   /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# ...                                                 ...    ...  ..    ...
# 5166  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5176  /work/data_pipeline/audio_data/preprocessing/w...  adult  25      f
# 5184  /work/data_pipeline/audio_data/preprocessing/w...  adult  32      m
# 5193  /work/data_pipeline/audio_data/preprocessing/w...  adult  26      m
# 5221  /work/data_pipeline/audio_data/preprocessing/w...  adult  22      f
#
#      predicted  correct  confidence       class2 predicted2  correct2  \
# 25       child     True    0.535122     teenager   teenager      True
# 30       child     True    0.539595  young child   teenager     False
# 51       child     True    0.837273  young child   teenager     False
# 77       child     True    0.706843     teenager   teenager      True
# 106      child     True    0.603261     teenager   teenager      True
# ...        ...      ...         ...          ...        ...       ...
# 5166     child    False    0.615883     teenager   teenager      True
# 5176     child    False    0.547296     teenager   teenager      True
# 5184     child    False    0.725351     teenager   teenager      True
# 5193     child    False    0.516995     teenager   teenager      True
# 5221     child    False    0.570162     teenager   teenager      True
#
#       confidence2
# 25       0.776003
# 30       0.745279
# 51       0.581458
# 77       0.832275
# 106      0.539050
# ...           ...
# 5166     0.697444
# 5176     0.921287
# 5184     0.718277
# 5193     0.925224
# 5221     0.568529
#
# [550 rows x 11 columns]

# %%
display(predicted_as_child[predicted_as_child['class2'] == 'teenager'])
# Out:
#                                                filepath  class age gender  \
# 5     /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# 6     /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# 23    /work/data_pipeline/audio_data/preprocessing/w...  child  12      f
# 24    /work/data_pipeline/audio_data/preprocessing/w...  child  11      f
# 25    /work/data_pipeline/audio_data/preprocessing/w...  child  15      f
# ...                                                 ...    ...  ..    ...
# 5197  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
# 5203  /work/data_pipeline/audio_data/preprocessing/w...  adult  33      f
# 5221  /work/data_pipeline/audio_data/preprocessing/w...  adult  22      f
# 5233  /work/data_pipeline/audio_data/preprocessing/w...  adult  20      f
# 5243  /work/data_pipeline/audio_data/preprocessing/w...  adult  21      f
#
#      predicted  correct  confidence    class2   predicted2  correct2  \
# 5        child     True    0.789358  teenager  young child     False
# 6        child     True    0.632592  teenager  young child     False
# 23       child     True    0.975165  teenager  young child     False
# 24       child     True    0.953602  teenager  young child     False
# 25       child     True    0.535122  teenager     teenager      True
# ...        ...      ...         ...       ...          ...       ...
# 5197     child    False    0.841786  teenager  young child     False
# 5203     child    False    0.954465  teenager  young child     False
# 5221     child    False    0.570162  teenager     teenager      True
# 5233     child    False    0.519641  teenager  young child     False
# 5243     child    False    0.929455  teenager  young child     False
#
#       confidence2
# 5        0.803227
# 6        0.898097
# 23       0.962019
# 24       0.966178
# 25       0.776003
# ...           ...
# 5197     0.798248
# 5203     0.936837
# 5221     0.568529
# 5233     0.593435
# 5243     0.841027
#
# [1664 rows x 11 columns]
