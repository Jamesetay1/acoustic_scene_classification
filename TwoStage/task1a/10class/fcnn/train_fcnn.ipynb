# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import numpy as np
import keras
import tensorflow
from keras.optimizers import SGD

import sys
sys.path.append("..")
from utils import *
from funcs import *

from fcnn_att import model_fcnn
from DCASE_training_functions import *

from tensorflow import ConfigProto
from tensorflow import InteractiveSession

# %load_ext autoreload
# %autoreload 2

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)


# Please put your csv file for train and validation here.
# If you dont generate the extra augmented data, please use 
# ../evaluation_setup/fold1_train.csv and delete the aug_csv part
train_csv = '../evaluation_setup_v2/fold1_train.csv'
val_csv = '../evaluation_setup_v2/fold1_evaluate.csv'
aug_csv = '../evaluation_setup_v2/fold1_train.csv'
#aug_csv = 'evaluation_setup/fold1_train_a_2003.csv'

feat_path = '../features/logmel128_scaled/'
#aug_path = 'features/logmel128_reverb_scaled/'

experiments = 'training_sample_run/'

if not os.path.exists(experiments):
    os.makedirs(experiments)
# Out:
# Using TensorFlow backend.

# %%
#train_aug_csv = generate_train_aug_csv(train_csv, aug_csv, feat_path, aug_path, experiments)
train_aug_csv = train_csv

num_audio_channels = 1
num_freq_bin = 128
num_classes = 10
max_lr = 0.1
batch_size = 32
num_epochs = 50
mixup_alpha = 0.4
crop_length = 400
sample_num = len(open(train_aug_csv, 'r').readlines()) - 1
print(f'Numbers of training samples: {sample_num}')


# compute delta and delta delta for validation data
data_val, y_val = load_data_2020(feat_path, val_csv, num_freq_bin, 'logmel')
print(f'y values: {y_val}')
print(f'validation data shape: {data_val.shape}')


data_deltas_val = deltas(data_val)
print(f'validation data deltas shape: {data_deltas_val.shape}')

data_deltas_deltas_val = deltas(data_deltas_val)
print(f'validation data delta deltas shape: {data_deltas_val.shape}')

data_val = np.concatenate((data_val[:,:,4:-4,:],data_deltas_val[:,:,2:-2,:],data_deltas_deltas_val),axis=-1)
print(f'validation data concat shape: {data_val.shape}')

y_val = keras.utils.to_categorical(y_val, num_classes)
# Out:
# Numbers of training samples: 13962
# y values: [0 0 0 ... 9 9 9]
# validation data shape: (2968, 128, 431, 1)
# validation data deltas shape: (2968, 128, 427, 1)
# validation data delta deltas shape: (2968, 128, 427, 1)
# validation data delta deltas shape: (2968, 128, 427, 1)

# %%
model = model_fcnn(num_classes, input_shape=[num_freq_bin, None, 3*num_audio_channels], num_filters=[48, 96, 192], wd=0)
# Out:
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /work/contractors/jtaylor/.conda/envs/d20-keras/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer =SGD(lr=max_lr,decay=1e-6, momentum=0.9, nesterov=False),
              metrics=['accuracy'])

model.summary()

lr_scheduler = LR_WarmRestart(nbatch=np.ceil(sample_num/batch_size), Tmult=2,
                              initial_lr=max_lr, min_lr=max_lr*1e-4,
                              epochs_restart = [3.0, 7.0, 15.0, 31.0, 63.0,127.0]) 
save_path = experiments + "/model-{epoch:02d}-{val_acc:.4f}.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(save_path, monitor='val_acc', verbose=1, save_best_only=False, mode='max')
callbacks = [lr_scheduler, checkpoint]
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, None, 3) 0
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, None, 3) 12          input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 132, None, 3) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, None, 144 10800       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, None, 144 576         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, None, 144 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 66, None, 144 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, None, 144 186624      zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, None, 144 576         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, None, 144 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, None, 144 0           activation_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 34, None, 144 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, None, 288 373248      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, None, 288 1152        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, None, 288 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 34, None, 288 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, None, 288 746496      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, None, 288 1152        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, None, 288 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, None, 288 0           activation_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 18, None, 288 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, None, 576 1492992     zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, None, 576 2304        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, None, 576 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, None, 576 0           activation_5[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 18, None, 576 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, None, 576 2985984     zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, None, 576 2304        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, None, 576 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, None, 576 0           activation_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 18, None, 576 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, None, 576 2985984     zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, None, 576 2304        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, None, 576 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, None, 576 0           activation_7[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 18, None, 576 0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, None, 576 2985984     zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, None, 576 2304        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, None, 576 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, None, 576) 0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, None, 10)  5760        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, None, 10)  20          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, None, 10)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, None, 10)  20          activation_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 10)           0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 10)           0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 10)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 10)     0           global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 5)      55          reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 10)     60          dense_1[0][0]
#                                                                  dense_1[1][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 1, 10)     0           dense_2[0][0]
#                                                                  dense_2[1][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 10)     0           add_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 8, None, 10)  0           batch_normalization_11[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 10)           0           multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 10)           0           global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 11,786,711
# Trainable params: 11,780,329
# Non-trainable params: 6,382
# __________________________________________________________________________________________________

# %%
# Due to the memory limitation, in the training stage we split the training data
train_data_generator = Generator_timefreqmask_withdelta_splitted(feat_path, train_aug_csv, num_freq_bin,
                              batch_size=batch_size,
                              alpha=mixup_alpha,
                              crop_length=crop_length, splitted_num=20, classes=10)()

history = model.fit_generator(train_data_generator,
                              validation_data=(data_val, y_val),
                              epochs=num_epochs, 
                              verbose=1, 
                              workers=4,
                              max_queue_size = 100,
                              callbacks=callbacks,
                              steps_per_epoch=np.ceil(sample_num/batch_size)
                              )
# Out:
# Epoch 1/50
# 437/437 [==============================] - 186s 426ms/step - loss: 1.9214 - acc: 0.3701 - val_loss: 2.0069 - val_acc: 0.2881
#
# LearningRate:0.050185
#
# Epoch 00001: saving model to training_sample_run//model-01-0.2881.hdf5
# Epoch 2/50
# 437/437 [==============================] - 185s 423ms/step - loss: 1.6992 - acc: 0.4929 - val_loss: 1.6095 - val_acc: 0.4380
#
# LearningRate:0.000010
#
# Epoch 00002: saving model to training_sample_run//model-02-0.4380.hdf5
# Epoch 3/50
# 247/437 [===============>..............] - ETA: 1:13 - loss: 1.7175 - acc: 0.4804
